# %%
! pip install streamlit
# Out:
# ...
#      ---------------------------------------- 0.0/44.3 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/44.3 kB ? eta -:--:--
#      -------------------------------------- 44.3/44.3 kB 549.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/9.0 MB 14.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/9.0 MB 12.5 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/9.0 MB 12.9 MB/s eta 0:00:01
#    --------- ------------------------------ 2.1/9.0 MB 11.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.3/9.0 MB 10.4 MB/s eta 0:00:01
#    ------------ --------------------------- 2.7/9.0 MB 10.2 MB/s eta 0:00:01
#    ------------ --------------------------- 2.8/9.0 MB 9.8 MB/s eta 0:00:01
#    ------------- -------------------------- 3.0/9.0 MB 8.2 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv('data/red_recarga_acceso_publico_2021.csv', sep = ';')
