# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 10.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 5.5 MB/s eta 0:00:00:00:01
# ...

# %%
import pymongo
client = pymongo.MongoClient("192.168.1.221", 27017)

# %%
db = client.data

# %%
for item in db.ventas.find():
    print(item)
# Out:
# {'_id': 1, 'producto': 'Laptop', 'categoria': 'Electrónica', 'precio': 1200, 'cantidad': 5, 'fecha': datetime.datetime(2023, 10, 1, 0, 0)}
# {'_id': 2, 'producto': 'Mouse', 'categoria': 'Electrónica', 'precio': 25, 'cantidad': 50, 'fecha': datetime.datetime(2023, 10, 2, 0, 0)}
# {'_id': 3, 'producto': 'Teclado', 'categoria': 'Electrónica', 'precio': 45, 'cantidad': 30, 'fecha': datetime.datetime(2023, 10, 3, 0, 0)}
# {'_id': 4, 'producto': 'Silla', 'categoria': 'Muebles', 'precio': 150, 'cantidad': 10, 'fecha': datetime.datetime(2023, 10, 4, 0, 0)}
# {'_id': 5, 'producto': 'Mesa', 'categoria': 'Muebles', 'precio': 300, 'cantidad': 5, 'fecha': datetime.datetime(2023, 10, 5, 0, 0)}
# {'_id': 6, 'producto': 'Monitor', 'categoria': 'Electrónica', 'precio': 200, 'cantidad': 20, 'fecha': datetime.datetime(2023, 10, 6, 0, 0)}
# {'_id': 7, 'producto': 'Lámpara', 'categoria': 'Muebles', 'precio': 50, 'cantidad': 15, 'fecha': datetime.datetime(2023, 10, 7, 0, 0)}
# ...

# %%
import pandas as pd
cursor = db.products.find()

# %%
cursor = db.products.aggregate([
    { "$unwind": "$variants" }
]);

# %%
list_cursor = list(cursor)
df = pd.DataFrame(list_cursor)
df.head
# Out:
# <bound method NDFrame.head of                         _id                              name  \
# 0  692d7961e05a308f84eae954         Café Arábica Premium 250g
# 1  692d7961e05a308f84eae954         Café Arábica Premium 250g
# 2  692d7961e05a308f84eae956        Auriculares Bluetooth X200
# 3  692d7961e05a308f84eae956        Auriculares Bluetooth X200
# 4  692d7961e05a308f84eae957  Camiseta Unisex Algodón Orgánico
# 5  692d7961e05a308f84eae957  Camiseta Unisex Algodón Orgánico
# 6  692d7961e05a308f84eae957  Camiseta Unisex Algodón Orgánico
# 7  692d7961e05a308f84eae957  Camiseta Unisex Algodón Orgánico
# 8  692d7961e05a308f84eae958        Hamburguesa Vegana Gourmet
# 9  692d7961e05a308f84eae958        Hamburguesa Vegana Gourmet
#
#                                slug      category  price  stock  \
# 0         cafe-arabica-premium-250g       bebidas   6.95    120
# 1         cafe-arabica-premium-250g       bebidas   6.95    120
# ...
