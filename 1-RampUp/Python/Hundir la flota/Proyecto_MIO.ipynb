# %%
#Función para crear tablero en blanco
def crear_tablero(lados):
    tablero=[]
    for elemento in range(0,lados,1):
        fila = []
        for elemento in range (0,lados,1):
            fila.append(" ")
        tablero.append(fila)
    return tablero


#Funcion para imprimir tablero
def imprimir_tablero(tablero):
    for elemento in tablero:
        print(" | ".join(elemento))

#Función para pintar los barcos en el tablero
def pintar_barcos(barcos,tablero):
    for valor in barcos.values():
        for elemento in valor:
            i = elemento[0] - 1
            j = elemento[1] - 1
            tablero[i][j] = "B"
    return tablero

# %%
#Como base necesito tres tableros, los tableros de ambos jugadores y uno donde registrar los disparos que se hagan
tablero_maquina = crear_tablero(10)
tablero_jugador = crear_tablero(10)
tablero_disparos = crear_tablero(10)

#Generar las posiciones de los barcos

#Variables barco para el jugador humano
barcos_jh = {
"barco4_1" : [[9,2],[9,3],[9,4],[9,5]],
"barco3_1" : [[1,1],[2,1],[3,1]],
"barco3_2" : [[5,3],[5,4],[5,5]],
"barco2_1" : [[2,4],[2,5]],
"barco2_2" : [[5,7],[6,7]],
"barco2_3" : [[6,9],[7,9]],
"barco1_1" : [[7,4]],
"barco1_2" : [[2,8]],
"barco1_3" : [[10,8]],
"barco1_4" : [[4,10]],
}

#Variables barcos para el jugador máquina
barcos_m = {
    "barco4_1": [[2,2], [2,3], [2,4], [2,5]],
    "barco3_1": [[7,8], [8,8], [9,8]],
    "barco3_2": [[4,1], [5,1], [6,1]],
    "barco2_1": [[8,3], [8,4]],
    "barco2_2": [[1,7], [1,8]],
    "barco2_3": [[5,5], [5,6]],
    "barco1_1": [[10,10]],
    "barco1_2": [[3,9]],
    "barco1_3": [[7,2]],
    "barco1_4": [[9,6]],
}

# Ubicar los barcos en los tableros

pintar_barcos(barcos_m,tablero_maquina)
imprimir_tablero(tablero_maquina)
print() 
pintar_barcos(barcos_jh,tablero_jugador)
imprimir_tablero(tablero_jugador)

#Generar un disparo y comprobar si ha dado o no en el barco

# disparo = list(input("Indica las coordenadas que queres disparar")) -- DESPUÉS SERÁ UN INPUT
disparo_jh = [1,5]

for elemento in disparo_jh:
    i = elemento[0]-1
    j = elemento[1]-1
    continuar = None
    if tablero_jugador[i][j] == "B":
        continuar = True
        print(f"Tocado en posición {i + 1},{j + 1}")
        




#Determinar si tiene que continuar el mismo jugador o no o si se termino la partida
# Out:
#   Cell In[39], line 55
#     print(f"Tocado en posición {i + 1},{j + 1})
#           ^
# SyntaxError: unterminated f-string literal (detected at line 55)

# %%
disparo = list(input("Indica las coordenadas que queres disparar"))
print(disparo,type(disparo))
# Out:
# ['1', '5'] <class 'list'>

# %%
"barco4_1" : [[9,2],[9,3],[9,4],[9,5]],
"barco3_1" : [[1,1],[2,1],[3,1]],
"barco3_2" : [[5,3],[5,4],[5,5]],
"barco2_1" : [[2,4],[2,5]],
"barco2_2" : [[5,7],[6,7]],
"barco2_3" : [[6,9],[7,9]],
"barco1_1" : [[7,4]],
"barco1_2" : [[2,8]],
"barco1_3" : [[2,9]],
"barco1_4" : [[4,10]],
